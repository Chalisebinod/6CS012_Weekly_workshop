# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import Libraries

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from PIL import Image

# %%
test_folder = "/content/drive/MyDrive/AI_ShivaSir/FruitinAmazon/test"
train_folder = "/content/drive/MyDrive/AI_ShivaSir/FruitinAmazon/train"

# %% [markdown]
# # Visualize Data

# %%
# Get the list of class directories
class_names = [d for d in os.listdir(train_folder) if os.path.isdir(os.path.join(train_folder, d))]

# Select one random image from each class
selected_images = []
for class_name in class_names:
    class_path = os.path.join(train_folder, class_name)
    images = os.listdir(class_path)

    # Randomly select one image
    if images:
        selected_image = random.choice(images)
        selected_images.append((class_name, os.path.join(class_path, selected_image)))


num_classes = len(selected_images)
cols = (num_classes + 1) // 2

fig, axes = plt.subplots(2, cols, figsize=(10, 6))
axes = axes.flatten()

for i, (class_name, image_path) in enumerate(selected_images):
    img = mpimg.imread(image_path)  # Load image
    axes[i].imshow(img)  # Show image
    axes[i].set_title(class_name)  # Corrected line

# Hide unused axes if any
for i in range(len(selected_images), len(axes)):
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check and Remove Corrupted Images

# %%
# Define the path to the train folder
train_folder = "/content/drive/MyDrive/AI_ShivaSir/FruitinAmazon/train"

# List to keep track of corrupted images
corrupted_images = []

# Iterate through each class subdirectory
for class_name in os.listdir(train_folder):
    class_path = os.path.join(train_folder, class_name)

    if os.path.isdir(class_path):  # Ensure it's a directory
        # Iterate through each image file in the class folder
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)

            try:
                # Try opening the image
                with Image.open(image_path) as img:
                    img.verify()  # Verify if the image is valid
            except (IOError, SyntaxError):
                # If an error occurs, it means the image is corrupted
                corrupted_images.append(image_path)
                os.remove(image_path)  # Remove the corrupted image
                print(f"Removed corrupted image: {image_path}")

# Check if any corrupted images were found
if not corrupted_images:
    print("No corrupted images found.")
else:
    print(f"Total corrupted images removed: {len(corrupted_images)}")
# Out:
# No corrupted images found.

# %% [markdown]
# # Create Training and Validation Datasets

# %%
# Define image size and batch size
img_height = 128 # Example image height
img_width = 128 # Example image width
batch_size = 32
validation_split = 0.2 # 80% training, 20% validation
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
     train_folder, labels='inferred',
     label_mode='int',
     image_size=(img_height, img_width),
     interpolation='nearest',
     batch_size= batch_size,
     shuffle=True,
     validation_split=validation_split,
     subset='training',
     seed=123
)
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.

# %% [markdown]
# # Data Augmentation

# %%
# Define image size and batch size
img_height = 128 # Example image height
img_width = 128 # Example image width
batch_size = 32
validation_split = 0.2 # 80% training, 20% validation
# Create a preprocessing layer for normalization
rescale = tf.keras.layers.Rescaling(1./255) # Normalize pixel values to [0, 1]
# Create training dataset with normalization
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_folder,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=True,
    validation_split=validation_split,
    subset='training',
    seed=123
)
# Apply the normalization (Rescaling) to the dataset
train_ds = train_ds.map(lambda x, y: (rescale(x), y))
# Create validation dataset with normalization
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_folder,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,
    validation_split=validation_split,
    subset='validation',
    seed=123
)
# Apply the normalization (Rescaling) to the validation dataset
val_ds = val_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.

# %% [markdown]
# # Define and Compile the Model

# %%
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Define augmentation (simpler first)
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
    layers.RandomWidth(0.2),  # Stretch width
    layers.RandomHeight(0.2),  # Stretch height
    layers.RandomContrast(0.3),
])


plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        augmented = data_augmentation(tf.expand_dims(images[i], axis=0), training=True)
        plt.subplot(3, 3, i + 1)
        plt.imshow(tf.clip_by_value(augmented[0], 0, 1).numpy())
        plt.axis("off")
plt.show()

# %% [markdown]
# # Train the Model

# %%
for image_batch, labels_batch in train_ds.take(1):  # Get one batch
    print(image_batch.shape)  # Prints (batch_size, height, width, channels)
    break
# Out:
# (32, 128, 128, 3)

# %%
input_shape = (32, 128, 128, 3)

# %% [markdown]
# # Add Batch Normalization Layer

# %%
from tensorflow.keras.layers import BatchNormalization
layer = BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True,
beta_initializer="zeros", gamma_initializer="ones")

# %% [markdown]
# # Add Dropout Layer

# %%
from tensorflow.keras.layers import Dropout
layer = Dropout(rate=0.25, noise_shape=None, seed=None)

# %% [markdown]
# # Define and Compile the Model

# %%
from tensorflow.keras import models
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

num_classes = len(class_names)

# Define the model
model = models.Sequential([
    # First Convolutional Block
    layers.Conv2D(32, (3, 3), padding='same', activation=None, input_shape=(128, 128, 3)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Second Convolutional Block
    layers.Conv2D(64, (3, 3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Flatten the output of the last Conv2D layer
    layers.Flatten(),

    # Fully Connected Layer
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.25),

    # Output Layer
    layers.Dense(10, activation='softmax')  # Assuming 10 classes
])


model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 128, 128, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 65536)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       8,388,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,409,802 (32.08 MB)
#  Trainable params: 8,409,610 (32.08 MB)
#  Non-trainable params: 192 (768.00 B)

# %% [markdown]
# # Train the Model

# %%
inputs = keras.Input(shape=input_shape)

# Compile the model
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Define callbacks
checkpoint_cb = callbacks.ModelCheckpoint("best_model.h5", save_best_only=True)
early_stopping_cb = callbacks.EarlyStopping(patience=5, restore_best_weights=True)

# Train the model
model.fit(
    train_ds,
    validation_data=val_ds,
    batch_size=8,
    epochs=2000,
    callbacks=[checkpoint_cb, early_stopping_cb],
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=2000
)

model.summary()
# Out:
# Epoch 1/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1603 - loss: 17.5016
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step - accuracy: 0.1584 - loss: 19.2997 - val_accuracy: 0.0000e+00 - val_loss: 2.1916
# Epoch 2/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.2617 - loss: 14.1789 - val_accuracy: 0.0000e+00 - val_loss: 2.4042
# Epoch 3/2000
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.1094 - loss: 5.7704
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.1172 - loss: 5.0670 - val_accuracy: 0.1111 - val_loss: 2.1279
# Epoch 4/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2049 - loss: 2.2432 - val_accuracy: 0.0000e+00 - val_loss: 2.4906
# Epoch 5/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.1389 - loss: 4.9044 - val_accuracy: 0.0556 - val_loss: 2.1432
# Epoch 6/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.1445 - loss: 2.0450 - val_accuracy: 0.0000e+00 - val_loss: 2.1875
# Epoch 7/2000
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.1797 - loss: 1.9395
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.2079 - loss: 1.9330 - val_accuracy: 0.0556 - val_loss: 1.9732
# Epoch 8/2000
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.2812 - loss: 1.9558
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.2587 - loss: 1.9510 - val_accuracy: 0.8333 - val_loss: 1.8047
# Epoch 9/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.1879 - loss: 2.0483 - val_accuracy: 0.0000e+00 - val_loss: 2.1652
# Epoch 10/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.2383 - loss: 1.9590 - val_accuracy: 0.1667 - val_loss: 2.1151
# Epoch 11/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.2648 - loss: 2.1578 - val_accuracy: 0.0000e+00 - val_loss: 2.1774
# Epoch 12/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.2765 - loss: 1.8832 - val_accuracy: 0.2778 - val_loss: 2.0998
# Epoch 13/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.2990 - loss: 1.9087 - val_accuracy: 0.0000e+00 - val_loss: 2.2029
# Epoch 1/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.1289 - loss: 2.0976 - val_accuracy: 0.6667 - val_loss: 2.0118
# Epoch 2/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.2335 - loss: 1.8557 - val_accuracy: 0.2222 - val_loss: 2.0251
# Epoch 3/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.3424 - loss: 1.7788 - val_accuracy: 0.1111 - val_loss: 2.0887
# Epoch 4/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3355 - loss: 1.7030 - val_accuracy: 0.6667 - val_loss: 1.9575
# Epoch 5/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.2431 - loss: 1.8695 - val_accuracy: 0.0000e+00 - val_loss: 2.2353
# Epoch 6/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.1879 - loss: 2.1083 - val_accuracy: 0.5556 - val_loss: 1.9943
# Epoch 7/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.2422 - loss: 1.9878 - val_accuracy: 0.3333 - val_loss: 2.0084
# Epoch 8/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.2609 - loss: 1.6563 - val_accuracy: 0.7778 - val_loss: 1.7989
# Epoch 9/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.2305 - loss: 2.1603 - val_accuracy: 0.0000e+00 - val_loss: 2.1327
# Epoch 10/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.2982 - loss: 1.6975 - val_accuracy: 0.0000e+00 - val_loss: 2.1174
# Epoch 11/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.2305 - loss: 1.8692 - val_accuracy: 0.2222 - val_loss: 2.0328
# Epoch 12/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.1997 - loss: 1.8299 - val_accuracy: 0.1111 - val_loss: 2.0783
# Epoch 13/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.2726 - loss: 1.5789 - val_accuracy: 0.3333 - val_loss: 1.9671
# Epoch 14/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.3190 - loss: 1.6450 - val_accuracy: 0.2222 - val_loss: 1.9143
# Epoch 15/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.3268 - loss: 1.7449 - val_accuracy: 0.1111 - val_loss: 2.0098
# Epoch 16/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.2326 - loss: 1.6842 - val_accuracy: 0.3889 - val_loss: 1.8840
# Epoch 17/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3294 - loss: 1.5130 - val_accuracy: 0.0000e+00 - val_loss: 2.0749
# Epoch 18/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.2422 - loss: 1.6667 - val_accuracy: 0.5000 - val_loss: 1.8832
# Epoch 19/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2865 - loss: 1.6048 - val_accuracy: 0.0556 - val_loss: 1.9356
# Epoch 20/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.2786 - loss: 1.7310 - val_accuracy: 0.0000e+00 - val_loss: 2.1891
# Epoch 21/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.2196 - loss: 1.8255 - val_accuracy: 0.0000e+00 - val_loss: 2.1778
# Epoch 22/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3455 - loss: 1.7613 - val_accuracy: 0.0000e+00 - val_loss: 2.3075
# Epoch 23/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.2244 - loss: 1.7949 - val_accuracy: 0.0000e+00 - val_loss: 2.1312
# Epoch 24/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3220 - loss: 1.7155 - val_accuracy: 0.0000e+00 - val_loss: 1.9814
# Epoch 25/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.3121 - loss: 1.6547 - val_accuracy: 0.7222 - val_loss: 1.5030
# Epoch 26/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.3624 - loss: 1.4532 - val_accuracy: 0.0556 - val_loss: 1.7924
# Epoch 27/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3503 - loss: 1.6049 - val_accuracy: 0.3333 - val_loss: 1.6704
# Epoch 28/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.4557 - loss: 1.3048 - val_accuracy: 0.0000e+00 - val_loss: 1.9261
# Epoch 29/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.2812 - loss: 1.6168 - val_accuracy: 0.0000e+00 - val_loss: 2.0883
# Epoch 30/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.3212 - loss: 1.6019 - val_accuracy: 0.0000e+00 - val_loss: 1.9224
# Epoch 31/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.3034 - loss: 1.5799 - val_accuracy: 0.3889 - val_loss: 1.6145
# Epoch 32/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4366 - loss: 1.4218 - val_accuracy: 0.7778 - val_loss: 1.4756
# Epoch 33/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.3446 - loss: 1.9221 - val_accuracy: 0.1667 - val_loss: 1.7316
# Epoch 34/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.4418 - loss: 1.4775 - val_accuracy: 0.3889 - val_loss: 1.6330
# Epoch 35/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.3524 - loss: 1.4993 - val_accuracy: 0.0000e+00 - val_loss: 1.8999
# Epoch 36/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 0.4262 - loss: 1.2764 - val_accuracy: 0.1667 - val_loss: 1.5633
# Epoch 37/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.3602 - loss: 1.7008 - val_accuracy: 0.6667 - val_loss: 1.6410
# Epoch 38/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.4175 - loss: 1.2945 - val_accuracy: 0.2778 - val_loss: 1.5156
# Epoch 39/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.3633 - loss: 1.4411 - val_accuracy: 0.3333 - val_loss: 1.5372
# Epoch 40/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.4961 - loss: 1.2892 - val_accuracy: 0.2222 - val_loss: 1.6912
# Epoch 41/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5373 - loss: 1.2451 - val_accuracy: 0.0556 - val_loss: 1.7771
# Epoch 42/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.4115 - loss: 1.2255 - val_accuracy: 0.0000e+00 - val_loss: 1.8598
# Epoch 43/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.4479 - loss: 1.2116 - val_accuracy: 0.5556 - val_loss: 1.5791
# Epoch 44/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.4253 - loss: 1.2787 - val_accuracy: 0.2778 - val_loss: 1.7435
# Epoch 45/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4674 - loss: 1.2153 - val_accuracy: 0.3889 - val_loss: 1.5596
# Epoch 46/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.5226 - loss: 1.1960 - val_accuracy: 0.1667 - val_loss: 1.7655
# Epoch 47/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3937 - loss: 1.2336 - val_accuracy: 0.2222 - val_loss: 1.9632
# Epoch 48/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5256 - loss: 1.1627 - val_accuracy: 0.2778 - val_loss: 1.5093
# Epoch 49/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.4627 - loss: 1.1908 - val_accuracy: 0.3333 - val_loss: 1.6239
# Epoch 50/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6133 - loss: 1.1151 - val_accuracy: 0.0000e+00 - val_loss: 2.1261
# Epoch 51/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.4566 - loss: 1.4540 - val_accuracy: 0.2222 - val_loss: 2.0664
# Epoch 52/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.3828 - loss: 2.1981 - val_accuracy: 0.7778 - val_loss: 1.0694
# Epoch 53/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.3533 - loss: 1.7772 - val_accuracy: 0.0000e+00 - val_loss: 2.0731
# Epoch 54/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.4627 - loss: 1.3546 - val_accuracy: 0.0000e+00 - val_loss: 2.1409
# Epoch 55/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5994 - loss: 1.1201 - val_accuracy: 0.0556 - val_loss: 1.8409
# Epoch 56/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4922 - loss: 1.1207 - val_accuracy: 0.0556 - val_loss: 1.9164
# Epoch 57/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.5208 - loss: 1.0739 - val_accuracy: 0.0556 - val_loss: 2.0413
# Epoch 58/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.5855 - loss: 1.0327 - val_accuracy: 0.8333 - val_loss: 0.8301
# Epoch 59/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.2196 - loss: 4.0318 - val_accuracy: 0.0556 - val_loss: 2.4575
# Epoch 60/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2079 - loss: 1.9761 - val_accuracy: 0.0000e+00 - val_loss: 2.5483
# Epoch 61/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.2717 - loss: 1.7519 - val_accuracy: 0.0000e+00 - val_loss: 2.5101
# Epoch 62/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.3121 - loss: 1.5379 - val_accuracy: 0.0000e+00 - val_loss: 2.2874
# Epoch 63/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.3811 - loss: 1.4179 - val_accuracy: 0.0556 - val_loss: 2.1659
# Epoch 64/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.4575 - loss: 1.2894 - val_accuracy: 0.0000e+00 - val_loss: 2.1740
# Epoch 65/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.3516 - loss: 1.3951 - val_accuracy: 0.0556 - val_loss: 2.0739
# Epoch 66/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.4466 - loss: 1.2503 - val_accuracy: 0.0556 - val_loss: 2.0769
# Epoch 67/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3885 - loss: 1.5928 - val_accuracy: 0.3889 - val_loss: 1.6078
# Epoch 68/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5430 - loss: 1.2683 - val_accuracy: 0.0556 - val_loss: 1.5903
# Epoch 69/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6150 - loss: 1.0542 - val_accuracy: 0.3889 - val_loss: 1.4110
# Epoch 70/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.6428 - loss: 0.9177 - val_accuracy: 0.0000e+00 - val_loss: 1.9190
# Epoch 71/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3398 - loss: 2.1043 - val_accuracy: 0.2222 - val_loss: 1.6791
# Epoch 72/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.4353 - loss: 1.3042 - val_accuracy: 0.2222 - val_loss: 1.7075
# Epoch 73/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.4019 - loss: 1.5455 - val_accuracy: 0.1111 - val_loss: 1.6304
# Epoch 74/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.5365 - loss: 1.0543 - val_accuracy: 0.0000e+00 - val_loss: 2.0151
# Epoch 75/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5924 - loss: 0.9144 - val_accuracy: 0.2778 - val_loss: 1.6497
# Epoch 76/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5187 - loss: 1.1079 - val_accuracy: 0.1111 - val_loss: 1.7907
# Epoch 77/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.4983 - loss: 1.0918 - val_accuracy: 0.0000e+00 - val_loss: 3.6431
# Epoch 78/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5751 - loss: 1.2205 - val_accuracy: 0.0556 - val_loss: 2.0803
# Epoch 79/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.5395 - loss: 1.2266 - val_accuracy: 0.0000e+00 - val_loss: 2.1510
# Epoch 80/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5972 - loss: 0.9098 - val_accuracy: 0.0556 - val_loss: 1.8648
# Epoch 81/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6328 - loss: 0.7658 - val_accuracy: 0.0556 - val_loss: 2.1284
# Epoch 82/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.6380 - loss: 0.8341 - val_accuracy: 0.1111 - val_loss: 1.6907
# Epoch 83/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6949 - loss: 0.8184 - val_accuracy: 0.1667 - val_loss: 1.8195
# Epoch 84/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.5924 - loss: 0.9663 - val_accuracy: 0.1111 - val_loss: 1.5814
# Epoch 85/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7027 - loss: 0.8784 - val_accuracy: 0.0000e+00 - val_loss: 4.0170
# Epoch 86/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.5690 - loss: 1.3780 - val_accuracy: 0.1111 - val_loss: 1.9401
# Epoch 87/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5434 - loss: 0.9301 - val_accuracy: 0.0000e+00 - val_loss: 2.1856
# Epoch 88/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5985 - loss: 1.1327 - val_accuracy: 0.3889 - val_loss: 1.5011
# Epoch 89/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7266 - loss: 0.7049 - val_accuracy: 0.4444 - val_loss: 1.2863
# Epoch 90/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6762 - loss: 0.7287 - val_accuracy: 0.5556 - val_loss: 1.1535
# Epoch 91/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.6823 - loss: 0.6689 - val_accuracy: 0.1667 - val_loss: 1.8107
# Epoch 92/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7548 - loss: 0.6908 - val_accuracy: 0.5000 - val_loss: 1.1848
# Epoch 93/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6211 - loss: 0.8026 - val_accuracy: 0.2778 - val_loss: 1.5526
# Epoch 94/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.6910 - loss: 0.8081 - val_accuracy: 0.2778 - val_loss: 1.3525
# Epoch 95/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.6063 - loss: 1.0374 - val_accuracy: 0.0556 - val_loss: 2.2184
# Epoch 96/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.5994 - loss: 0.8729 - val_accuracy: 0.8889 - val_loss: 0.6879
# Epoch 97/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.4223 - loss: 1.5833 - val_accuracy: 0.1667 - val_loss: 1.4637
# Epoch 98/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.4961 - loss: 1.1711 - val_accuracy: 0.0000e+00 - val_loss: 2.5067
# Epoch 99/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6437 - loss: 0.9535 - val_accuracy: 0.2222 - val_loss: 1.8809
# Epoch 100/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.6536 - loss: 0.8551 - val_accuracy: 0.2778 - val_loss: 1.4449
# Epoch 101/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7144 - loss: 0.7598 - val_accuracy: 0.6667 - val_loss: 1.1573
# Epoch 102/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6163 - loss: 0.8441 - val_accuracy: 0.4444 - val_loss: 1.3339
# Epoch 103/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.7804 - loss: 0.5646 - val_accuracy: 0.2778 - val_loss: 1.5458
# Epoch 104/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.6823 - loss: 0.7704 - val_accuracy: 0.0556 - val_loss: 2.3439
# Epoch 105/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.7539 - loss: 0.5652 - val_accuracy: 0.0000e+00 - val_loss: 1.9772
# Epoch 106/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6871 - loss: 0.6797 - val_accuracy: 0.3889 - val_loss: 1.3272
# Epoch 107/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6714 - loss: 0.6598 - val_accuracy: 0.2222 - val_loss: 1.3541
# Epoch 108/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7617 - loss: 0.6263 - val_accuracy: 0.6667 - val_loss: 1.0906
# Epoch 109/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6241 - loss: 0.8346 - val_accuracy: 0.3333 - val_loss: 1.4005
# Epoch 110/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7196 - loss: 0.6811 - val_accuracy: 0.0556 - val_loss: 1.6838
# Epoch 111/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6840 - loss: 0.7172 - val_accuracy: 0.3889 - val_loss: 1.6568
# Epoch 112/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.7027 - loss: 1.0214 - val_accuracy: 0.2222 - val_loss: 1.1327
# Epoch 113/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6428 - loss: 1.0166 - val_accuracy: 0.0556 - val_loss: 1.8314
# Epoch 114/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6506 - loss: 0.8326 - val_accuracy: 0.7778 - val_loss: 0.8351
# Epoch 115/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.7283 - loss: 0.6569 - val_accuracy: 0.2222 - val_loss: 1.3952
# Epoch 116/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.4045 - loss: 2.6950 - val_accuracy: 0.2778 - val_loss: 1.3640
# Epoch 117/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.6063 - loss: 1.0236 - val_accuracy: 0.7778 - val_loss: 0.8259
# Epoch 118/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7361 - loss: 0.6382 - val_accuracy: 0.6667 - val_loss: 1.0408
# Epoch 119/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.6949 - loss: 0.6799 - val_accuracy: 0.7222 - val_loss: 0.8829
# Epoch 120/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.6458 - loss: 0.8635 - val_accuracy: 0.0000e+00 - val_loss: 3.1813
# Epoch 121/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.5751 - loss: 1.3037 - val_accuracy: 0.5000 - val_loss: 1.1669
# Epoch 122/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7865 - loss: 0.6324 - val_accuracy: 0.1111 - val_loss: 1.8074
# Epoch 123/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.6901 - loss: 0.6940 - val_accuracy: 0.5000 - val_loss: 1.1758
# Epoch 124/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7678 - loss: 0.6389 - val_accuracy: 0.4444 - val_loss: 1.3087
# Epoch 125/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7205 - loss: 0.6441 - val_accuracy: 0.6111 - val_loss: 1.1471
# Epoch 126/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8121 - loss: 0.4909 - val_accuracy: 0.6667 - val_loss: 0.9059
# Epoch 127/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6636 - loss: 0.7134 - val_accuracy: 0.1111 - val_loss: 1.7870
# Epoch 128/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6224 - loss: 0.8015 - val_accuracy: 0.6111 - val_loss: 1.1082
# Epoch 129/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.8030 - loss: 0.4639 - val_accuracy: 0.7778 - val_loss: 0.9891
# Epoch 130/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7826 - loss: 0.4757 - val_accuracy: 0.1667 - val_loss: 1.9573
# Epoch 131/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7010 - loss: 0.9145 - val_accuracy: 0.6667 - val_loss: 1.2874
# Epoch 132/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7639 - loss: 0.5882 - val_accuracy: 0.5000 - val_loss: 1.0855
# Epoch 133/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8108 - loss: 0.4176 - val_accuracy: 0.7778 - val_loss: 0.7905
# Epoch 134/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.6107 - loss: 0.7803 - val_accuracy: 0.6667 - val_loss: 0.9905
# Epoch 135/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8477 - loss: 0.3966 - val_accuracy: 0.8333 - val_loss: 0.6989
# Epoch 136/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8160 - loss: 0.4654 - val_accuracy: 0.7222 - val_loss: 0.8962
# Epoch 137/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8247 - loss: 0.3590 - val_accuracy: 0.6667 - val_loss: 0.8546
# Epoch 138/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8090 - loss: 0.3956 - val_accuracy: 0.7778 - val_loss: 0.9088
# Epoch 139/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7708 - loss: 0.5468 - val_accuracy: 0.7222 - val_loss: 0.8739
# Epoch 140/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7678 - loss: 0.4750 - val_accuracy: 0.5556 - val_loss: 1.1960
# Epoch 141/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.8789 - loss: 0.3050 - val_accuracy: 0.8333 - val_loss: 0.6414
# Epoch 142/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8307 - loss: 0.4272 - val_accuracy: 0.8333 - val_loss: 0.5840
# Epoch 143/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.8563 - loss: 0.3102 - val_accuracy: 0.8333 - val_loss: 0.5100
# Epoch 144/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8277 - loss: 0.5025 - val_accuracy: 0.8333 - val_loss: 0.7235
# Epoch 145/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8533 - loss: 0.3853 - val_accuracy: 0.7222 - val_loss: 1.1121
# Epoch 146/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8602 - loss: 0.3921 - val_accuracy: 0.7778 - val_loss: 0.9863
# Epoch 147/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6949 - loss: 0.6014 - val_accuracy: 0.7778 - val_loss: 0.7066
# Epoch 148/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.8503 - loss: 0.4108 - val_accuracy: 0.7778 - val_loss: 0.5890
# Epoch 149/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8082 - loss: 0.5097 - val_accuracy: 0.7778 - val_loss: 0.4176
# Epoch 150/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 0.8720 - loss: 0.3150 - val_accuracy: 0.8333 - val_loss: 0.3391
# Epoch 151/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8581 - loss: 0.3087 - val_accuracy: 0.8333 - val_loss: 0.4148
# Epoch 152/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7135 - loss: 0.6302 - val_accuracy: 0.7778 - val_loss: 0.9482
# Epoch 153/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.6940 - loss: 0.8795 - val_accuracy: 0.7778 - val_loss: 0.5076
# Epoch 154/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8207 - loss: 0.3967 - val_accuracy: 0.8333 - val_loss: 0.4418
# Epoch 155/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8338 - loss: 0.4252 - val_accuracy: 0.7778 - val_loss: 0.4733
# Epoch 156/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8494 - loss: 0.3772 - val_accuracy: 0.8333 - val_loss: 0.5785
# Epoch 157/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8199 - loss: 0.4028 - val_accuracy: 0.7222 - val_loss: 0.6312
# Epoch 158/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7925 - loss: 0.4771 - val_accuracy: 0.8889 - val_loss: 0.5231
# Epoch 159/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.8051 - loss: 0.4043 - val_accuracy: 0.8889 - val_loss: 0.5434
# Epoch 160/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.8299 - loss: 0.3490 - val_accuracy: 0.8889 - val_loss: 0.5552
# Epoch 161/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8260 - loss: 0.4459 - val_accuracy: 0.8889 - val_loss: 0.5761
# Epoch 162/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7075 - loss: 0.5243 - val_accuracy: 0.6111 - val_loss: 1.1801
# Epoch 163/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.7756 - loss: 0.4261 - val_accuracy: 0.6667 - val_loss: 0.9633
# Epoch 164/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.8524 - loss: 0.4180 - val_accuracy: 0.6667 - val_loss: 1.2208
# Epoch 165/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8672 - loss: 0.3967 - val_accuracy: 0.7778 - val_loss: 0.9479
# Epoch 166/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8702 - loss: 0.3405 - val_accuracy: 0.7222 - val_loss: 0.9964
# Epoch 167/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8494 - loss: 0.3437 - val_accuracy: 0.7778 - val_loss: 0.8752
# Epoch 168/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8160 - loss: 0.4838 - val_accuracy: 0.7778 - val_loss: 0.8207
# Epoch 169/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.9154 - loss: 0.3019 - val_accuracy: 0.7778 - val_loss: 0.7647
# Epoch 170/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8641 - loss: 0.3894 - val_accuracy: 0.7778 - val_loss: 0.6983
# Epoch 171/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8307 - loss: 0.3675 - val_accuracy: 0.7778 - val_loss: 0.7167
# Epoch 172/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8494 - loss: 0.3463 - val_accuracy: 0.8333 - val_loss: 0.7413
# Epoch 173/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.8424 - loss: 0.3015 - val_accuracy: 0.7778 - val_loss: 0.6716
# Epoch 174/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.8845 - loss: 0.3229 - val_accuracy: 0.7778 - val_loss: 0.8937
# Epoch 175/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.8268 - loss: 0.5157 - val_accuracy: 0.7778 - val_loss: 0.6689
# Epoch 176/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.8602 - loss: 0.3532 - val_accuracy: 0.7778 - val_loss: 0.6696
# Epoch 177/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.7795 - loss: 0.4915 - val_accuracy: 0.7778 - val_loss: 0.7388
# Epoch 178/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8082 - loss: 0.4560 - val_accuracy: 0.8889 - val_loss: 0.6079
# Epoch 179/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9154 - loss: 0.2734 - val_accuracy: 0.8889 - val_loss: 0.7176
# Epoch 180/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8043 - loss: 0.3586 - val_accuracy: 0.8889 - val_loss: 0.6141
# Epoch 181/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8572 - loss: 0.3495 - val_accuracy: 0.8889 - val_loss: 0.5116
# Epoch 182/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8702 - loss: 0.3235 - val_accuracy: 0.8889 - val_loss: 0.4940
# Epoch 183/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7452 - loss: 0.5180 - val_accuracy: 0.8889 - val_loss: 0.4448
# Epoch 184/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.7826 - loss: 0.4273 - val_accuracy: 0.8889 - val_loss: 0.4720
# Epoch 185/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8641 - loss: 0.4078 - val_accuracy: 0.8333 - val_loss: 0.4560
# Epoch 186/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.7943 - loss: 0.4398 - val_accuracy: 0.8333 - val_loss: 0.3909
# Epoch 187/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8828 - loss: 0.2646 - val_accuracy: 0.8889 - val_loss: 0.4603
# Epoch 188/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8780 - loss: 0.3240 - val_accuracy: 0.8333 - val_loss: 0.5814
# Epoch 189/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.8867 - loss: 0.3323 - val_accuracy: 0.8333 - val_loss: 0.6421
# Epoch 190/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8229 - loss: 0.3700 - val_accuracy: 0.8333 - val_loss: 0.5890
# Epoch 191/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9036 - loss: 0.2989 - val_accuracy: 0.7778 - val_loss: 1.0025
# Epoch 192/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.7374 - loss: 0.6194 - val_accuracy: 0.8333 - val_loss: 0.5383
# Epoch 193/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8385 - loss: 0.4511 - val_accuracy: 0.7778 - val_loss: 0.6271
# Epoch 194/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.7305 - loss: 0.5295 - val_accuracy: 0.8889 - val_loss: 0.4683
# Epoch 195/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8138 - loss: 0.3943 - val_accuracy: 0.8333 - val_loss: 0.4648
# Epoch 196/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.8060 - loss: 0.3551 - val_accuracy: 0.8333 - val_loss: 0.4500
# Epoch 197/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.7569 - loss: 0.4811 - val_accuracy: 0.8333 - val_loss: 0.4906
# Epoch 198/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7617 - loss: 0.5075 - val_accuracy: 0.8333 - val_loss: 0.6293
# Epoch 199/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7431 - loss: 0.7946 - val_accuracy: 0.8889 - val_loss: 0.3190
# Epoch 200/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.8160 - loss: 0.4425 - val_accuracy: 0.8889 - val_loss: 0.3430
# Epoch 201/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7491 - loss: 0.5105 - val_accuracy: 0.8333 - val_loss: 0.3450
# Epoch 202/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.8589 - loss: 0.4104 - val_accuracy: 0.8333 - val_loss: 0.3584
# Epoch 203/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.8299 - loss: 0.4469 - val_accuracy: 0.8889 - val_loss: 0.4469
# Epoch 204/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.8238 - loss: 0.4021 - val_accuracy: 0.8333 - val_loss: 0.3768
# Epoch 205/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8819 - loss: 0.2819 - val_accuracy: 0.8333 - val_loss: 0.4306
# Epoch 206/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8260 - loss: 0.4457 - val_accuracy: 0.8333 - val_loss: 0.4822
# Epoch 207/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8377 - loss: 0.3071 - val_accuracy: 0.8333 - val_loss: 0.3986
# Epoch 208/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8750 - loss: 0.3580 - val_accuracy: 0.8333 - val_loss: 0.3783
# Epoch 209/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7934 - loss: 0.4539 - val_accuracy: 0.8889 - val_loss: 0.3959
# Epoch 210/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.8346 - loss: 0.3727 - val_accuracy: 0.7778 - val_loss: 0.8045
# Epoch 211/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.7943 - loss: 0.4863 - val_accuracy: 0.7778 - val_loss: 0.8838
# Epoch 212/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.7639 - loss: 0.7860 - val_accuracy: 0.8889 - val_loss: 0.3859
# Epoch 213/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8021 - loss: 0.4374 - val_accuracy: 0.8333 - val_loss: 0.4090
# Epoch 214/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8555 - loss: 0.3195 - val_accuracy: 0.8333 - val_loss: 0.3603
# Epoch 215/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8268 - loss: 0.4299 - val_accuracy: 0.8333 - val_loss: 0.3974
# Epoch 216/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8563 - loss: 0.2809 - val_accuracy: 0.8889 - val_loss: 0.4366
# Epoch 217/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.9062 - loss: 0.2598 - val_accuracy: 0.7778 - val_loss: 0.5367
# Epoch 218/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.9036 - loss: 0.2109 - val_accuracy: 0.8333 - val_loss: 0.4636
# Epoch 219/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8455 - loss: 0.3756 - val_accuracy: 0.8333 - val_loss: 0.4228
# Epoch 220/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8346 - loss: 0.3540 - val_accuracy: 0.7778 - val_loss: 0.4672
# Epoch 221/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8524 - loss: 0.2839 - val_accuracy: 0.8333 - val_loss: 0.4947
# Epoch 222/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.8672 - loss: 0.2924 - val_accuracy: 0.7778 - val_loss: 0.7442
# Epoch 223/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8385 - loss: 0.4743 - val_accuracy: 0.8889 - val_loss: 0.3787
# Epoch 224/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - accuracy: 0.8151 - loss: 0.4024 - val_accuracy: 0.8889 - val_loss: 0.3992
# Epoch 225/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8160 - loss: 0.4148 - val_accuracy: 0.5556 - val_loss: 1.5058
# Epoch 226/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7522 - loss: 0.5831 - val_accuracy: 0.8889 - val_loss: 0.4422
# Epoch 227/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8828 - loss: 0.2493 - val_accuracy: 0.8889 - val_loss: 0.4866
# Epoch 228/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 0.7973 - loss: 0.4430 - val_accuracy: 0.8889 - val_loss: 0.4549
# Epoch 229/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8563 - loss: 0.2945 - val_accuracy: 0.8889 - val_loss: 0.4520
# Epoch 230/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8524 - loss: 0.2959 - val_accuracy: 0.8889 - val_loss: 0.4572
# Epoch 231/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 0.8928 - loss: 0.2188 - val_accuracy: 0.8889 - val_loss: 0.4685
# Epoch 232/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8581 - loss: 0.3208 - val_accuracy: 0.8333 - val_loss: 0.6524
# Epoch 233/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8407 - loss: 0.3381 - val_accuracy: 0.8333 - val_loss: 0.6624
# Epoch 234/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8780 - loss: 0.3171 - val_accuracy: 0.8889 - val_loss: 0.5236
# Epoch 235/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8859 - loss: 0.2936 - val_accuracy: 0.8889 - val_loss: 0.5238
# Epoch 236/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7609 - loss: 0.4873 - val_accuracy: 0.8333 - val_loss: 0.5239
# Epoch 237/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.9036 - loss: 0.2263 - val_accuracy: 0.8333 - val_loss: 0.5382
# Epoch 238/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8602 - loss: 0.4022 - val_accuracy: 0.8333 - val_loss: 0.5921
# Epoch 239/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8641 - loss: 0.3200 - val_accuracy: 0.8333 - val_loss: 0.5812
# Epoch 240/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8160 - loss: 0.4256 - val_accuracy: 0.8889 - val_loss: 0.4743
# Epoch 241/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.9084 - loss: 0.2174 - val_accuracy: 0.8889 - val_loss: 0.5083
# Epoch 242/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9301 - loss: 0.1491 - val_accuracy: 0.8889 - val_loss: 0.4555
# Epoch 243/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7491 - loss: 0.4665 - val_accuracy: 0.8889 - val_loss: 0.4420
# Epoch 244/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8260 - loss: 0.3198 - val_accuracy: 0.8333 - val_loss: 0.4512
# Epoch 245/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8477 - loss: 0.4442 - val_accuracy: 0.8333 - val_loss: 0.3967
# Epoch 246/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.8316 - loss: 0.4021 - val_accuracy: 0.8889 - val_loss: 0.3507
# Epoch 247/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8494 - loss: 0.3265 - val_accuracy: 0.8889 - val_loss: 0.2778
# Epoch 248/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8555 - loss: 0.3137 - val_accuracy: 0.8889 - val_loss: 0.3125
# Epoch 249/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.8611 - loss: 0.3752 - val_accuracy: 0.8333 - val_loss: 0.3445
# Epoch 250/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8889 - loss: 0.3289 - val_accuracy: 0.8333 - val_loss: 0.3135
# Epoch 251/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8394 - loss: 0.3052 - val_accuracy: 0.8889 - val_loss: 0.2987
# Epoch 252/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.8385 - loss: 0.3279 - val_accuracy: 0.8333 - val_loss: 0.2802
# Epoch 253/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8555 - loss: 0.2226 - val_accuracy: 0.8333 - val_loss: 0.4140
# Epoch 254/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.8750 - loss: 0.2254 - val_accuracy: 0.8333 - val_loss: 0.4318
# Epoch 255/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9145 - loss: 0.1943 - val_accuracy: 0.8333 - val_loss: 0.4174
# Epoch 256/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8494 - loss: 0.3597 - val_accuracy: 0.8333 - val_loss: 0.4329
# Epoch 257/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8641 - loss: 0.3328 - val_accuracy: 0.8333 - val_loss: 0.5236
# Epoch 258/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.8650 - loss: 0.2927 - val_accuracy: 0.7778 - val_loss: 0.7729
# Epoch 259/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7235 - loss: 0.8403 - val_accuracy: 0.8333 - val_loss: 0.5411
# Epoch 260/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8633 - loss: 0.4304 - val_accuracy: 0.8333 - val_loss: 0.3985
# Epoch 261/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.8741 - loss: 0.3021 - val_accuracy: 0.8889 - val_loss: 0.3589
# Epoch 262/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7904 - loss: 0.3908 - val_accuracy: 0.7778 - val_loss: 0.5594
# Epoch 263/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8750 - loss: 0.3305 - val_accuracy: 0.8333 - val_loss: 0.4351
# Epoch 264/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8819 - loss: 0.2723 - val_accuracy: 0.8333 - val_loss: 0.4378
# Epoch 265/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9054 - loss: 0.2653 - val_accuracy: 0.8889 - val_loss: 0.4602
# Epoch 266/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8021 - loss: 0.4489 - val_accuracy: 0.8333 - val_loss: 0.5057
# Epoch 267/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8867 - loss: 0.3042 - val_accuracy: 0.8333 - val_loss: 0.5695
# Epoch 268/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8385 - loss: 0.3214 - val_accuracy: 0.8333 - val_loss: 0.5126
# Epoch 269/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9410 - loss: 0.2418 - val_accuracy: 0.8889 - val_loss: 0.4477
# Epoch 270/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8082 - loss: 0.4549 - val_accuracy: 0.8889 - val_loss: 0.5146
# Epoch 271/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9084 - loss: 0.2289 - val_accuracy: 0.8333 - val_loss: 0.5372
# Epoch 272/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8238 - loss: 0.3353 - val_accuracy: 0.8333 - val_loss: 0.5529
# Epoch 273/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8602 - loss: 0.3905 - val_accuracy: 0.7778 - val_loss: 0.6627
# Epoch 274/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8641 - loss: 0.2910 - val_accuracy: 0.8333 - val_loss: 0.5850
# Epoch 275/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8433 - loss: 0.3483 - val_accuracy: 0.8889 - val_loss: 0.3071
# Epoch 276/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8819 - loss: 0.3299 - val_accuracy: 0.8889 - val_loss: 0.3840
# Epoch 277/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8828 - loss: 0.2691 - val_accuracy: 0.8889 - val_loss: 0.3376
# Epoch 278/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8555 - loss: 0.3150 - val_accuracy: 0.8889 - val_loss: 0.4262
# Epoch 279/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9349 - loss: 0.2021 - val_accuracy: 0.8889 - val_loss: 0.4252
# Epoch 280/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.8859 - loss: 0.3827 - val_accuracy: 0.8889 - val_loss: 0.5006
# Epoch 281/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8819 - loss: 0.3023 - val_accuracy: 0.8889 - val_loss: 0.4682
# Epoch 282/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9349 - loss: 0.2053 - val_accuracy: 0.8333 - val_loss: 0.6805
# Epoch 283/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 0.9084 - loss: 0.2893 - val_accuracy: 0.8333 - val_loss: 0.5714
# Epoch 284/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9271 - loss: 0.2193 - val_accuracy: 0.8889 - val_loss: 0.5612
# Epoch 285/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8090 - loss: 0.3722 - val_accuracy: 0.8889 - val_loss: 0.5376
# Epoch 286/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8377 - loss: 0.3500 - val_accuracy: 0.8889 - val_loss: 0.5099
# Epoch 287/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8837 - loss: 0.2042 - val_accuracy: 0.8889 - val_loss: 0.5787
# Epoch 288/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8112 - loss: 0.3054 - val_accuracy: 0.8889 - val_loss: 0.6416
# Epoch 289/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8572 - loss: 0.3109 - val_accuracy: 0.8889 - val_loss: 0.3950
# Epoch 290/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8594 - loss: 0.4444 - val_accuracy: 0.8889 - val_loss: 0.4235
# Epoch 291/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8928 - loss: 0.3550 - val_accuracy: 0.8889 - val_loss: 0.4781
# Epoch 292/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8207 - loss: 0.4156 - val_accuracy: 0.8889 - val_loss: 0.4906
# Epoch 293/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8594 - loss: 0.3278 - val_accuracy: 0.8889 - val_loss: 0.3651
# Epoch 294/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9123 - loss: 0.1791 - val_accuracy: 0.8889 - val_loss: 0.4386
# Epoch 295/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8524 - loss: 0.3155 - val_accuracy: 0.8889 - val_loss: 0.4833
# Epoch 296/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.8806 - loss: 0.2443 - val_accuracy: 0.8889 - val_loss: 0.5566
# Epoch 297/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.8663 - loss: 0.2996 - val_accuracy: 0.8889 - val_loss: 0.5506
# Epoch 298/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8602 - loss: 0.2843 - val_accuracy: 0.8889 - val_loss: 0.5556
# Epoch 299/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.9488 - loss: 0.1915 - val_accuracy: 0.8333 - val_loss: 0.6609
# Epoch 300/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.8720 - loss: 0.2704 - val_accuracy: 0.8333 - val_loss: 0.6561
# Epoch 301/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8377 - loss: 0.2946 - val_accuracy: 0.8333 - val_loss: 0.6659
# Epoch 302/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9301 - loss: 0.1505 - val_accuracy: 0.8889 - val_loss: 0.5728
# Epoch 303/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9488 - loss: 0.2040 - val_accuracy: 0.8889 - val_loss: 0.4889
# Epoch 304/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.8859 - loss: 0.2339 - val_accuracy: 0.8889 - val_loss: 0.5219
# Epoch 305/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.9006 - loss: 0.2005 - val_accuracy: 0.8889 - val_loss: 0.5110
# Epoch 306/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8572 - loss: 0.3447 - val_accuracy: 0.8333 - val_loss: 0.6422
# Epoch 307/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8759 - loss: 0.3425 - val_accuracy: 0.8889 - val_loss: 0.4416
# Epoch 308/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8307 - loss: 0.3359 - val_accuracy: 0.8889 - val_loss: 0.3791
# Epoch 309/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8702 - loss: 0.2677 - val_accuracy: 0.8889 - val_loss: 0.3744
# Epoch 310/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 0.8247 - loss: 0.3921 - val_accuracy: 0.8889 - val_loss: 0.4311
# Epoch 311/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.8898 - loss: 0.2602 - val_accuracy: 0.8889 - val_loss: 0.4556
# Epoch 312/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8307 - loss: 0.3685 - val_accuracy: 0.8889 - val_loss: 0.4497
# Epoch 313/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.8507 - loss: 0.2188 - val_accuracy: 0.8889 - val_loss: 0.3558
# Epoch 314/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9301 - loss: 0.1564 - val_accuracy: 0.8889 - val_loss: 0.3578
# Epoch 315/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8759 - loss: 0.2867 - val_accuracy: 0.8889 - val_loss: 0.3671
# Epoch 316/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9440 - loss: 0.1793 - val_accuracy: 0.8889 - val_loss: 0.3683
# Epoch 317/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8611 - loss: 0.3253 - val_accuracy: 0.8889 - val_loss: 0.3681
# Epoch 318/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8485 - loss: 0.2827 - val_accuracy: 0.8889 - val_loss: 0.3553
# Epoch 319/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9045 - loss: 0.2759 - val_accuracy: 0.8889 - val_loss: 0.4010
# Epoch 320/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8377 - loss: 0.3671 - val_accuracy: 0.8889 - val_loss: 0.4164
# Epoch 321/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9410 - loss: 0.1426 - val_accuracy: 0.7778 - val_loss: 1.2273
# Epoch 322/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8268 - loss: 0.4018 - val_accuracy: 0.7778 - val_loss: 0.8355
# Epoch 323/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8819 - loss: 0.2678 - val_accuracy: 0.7778 - val_loss: 0.9780
# Epoch 324/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9036 - loss: 0.3117 - val_accuracy: 0.7778 - val_loss: 0.8733
# Epoch 325/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.9410 - loss: 0.1638 - val_accuracy: 0.7778 - val_loss: 0.7976
# Epoch 326/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8976 - loss: 0.2687 - val_accuracy: 0.8333 - val_loss: 0.6067
# Epoch 327/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8937 - loss: 0.2461 - val_accuracy: 0.7778 - val_loss: 0.7817
# Epoch 328/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8789 - loss: 0.2409 - val_accuracy: 0.7778 - val_loss: 0.5315
# Epoch 329/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8976 - loss: 0.2764 - val_accuracy: 0.7778 - val_loss: 0.7965
# Epoch 330/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8937 - loss: 0.3648 - val_accuracy: 0.7778 - val_loss: 0.6560
# Epoch 331/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8928 - loss: 0.2646 - val_accuracy: 0.7778 - val_loss: 0.7008
# Epoch 332/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9714 - loss: 0.1781 - val_accuracy: 0.7778 - val_loss: 0.7389
# Epoch 333/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.9379 - loss: 0.1811 - val_accuracy: 0.8333 - val_loss: 0.7037
# Epoch 334/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9045 - loss: 0.3035 - val_accuracy: 0.8333 - val_loss: 0.7028
# Epoch 335/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8316 - loss: 0.3478 - val_accuracy: 0.8889 - val_loss: 0.6649
# Epoch 336/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.8750 - loss: 0.2516 - val_accuracy: 0.8333 - val_loss: 0.6409
# Epoch 337/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.7795 - loss: 0.4426 - val_accuracy: 0.7778 - val_loss: 0.8572
# Epoch 338/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.9301 - loss: 0.1857 - val_accuracy: 0.8333 - val_loss: 0.6609
# Epoch 339/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.9792 - loss: 0.1305 - val_accuracy: 0.8333 - val_loss: 0.6232
# Epoch 340/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8789 - loss: 0.3278 - val_accuracy: 0.8333 - val_loss: 0.7236
# Epoch 341/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8945 - loss: 0.2404 - val_accuracy: 0.8333 - val_loss: 0.7411
# Epoch 342/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9162 - loss: 0.2172 - val_accuracy: 0.8889 - val_loss: 0.4829
# Epoch 343/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9566 - loss: 0.2380 - val_accuracy: 0.8889 - val_loss: 0.2539
# Epoch 344/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8819 - loss: 0.3145 - val_accuracy: 0.8889 - val_loss: 0.3789
# Epoch 345/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.8129 - loss: 0.3990 - val_accuracy: 0.8889 - val_loss: 0.3060
# Epoch 346/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9379 - loss: 0.1714 - val_accuracy: 0.6111 - val_loss: 0.9792
# Epoch 347/2000
# ...
# Epoch 1903/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9115 - loss: 0.1939 - val_accuracy: 0.8889 - val_loss: 0.4544
# Epoch 1904/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9488 - loss: 0.1478 - val_accuracy: 0.8889 - val_loss: 0.4771
# Epoch 1905/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9783 - loss: 0.1018 - val_accuracy: 0.9444 - val_loss: 0.4386
# Epoch 1906/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8898 - loss: 0.2599 - val_accuracy: 0.9444 - val_loss: 0.4729
# Epoch 1907/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9371 - loss: 0.1570 - val_accuracy: 0.9444 - val_loss: 0.4650
# Epoch 1908/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9813 - loss: 0.0445 - val_accuracy: 0.9444 - val_loss: 0.4698
# Epoch 1909/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9488 - loss: 0.1635 - val_accuracy: 0.9444 - val_loss: 0.4724
# Epoch 1910/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.8928 - loss: 0.2967 - val_accuracy: 0.8333 - val_loss: 0.4832
# Epoch 1911/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - accuracy: 0.9705 - loss: 0.1309 - val_accuracy: 0.8333 - val_loss: 0.4972
# Epoch 1912/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 0.9332 - loss: 0.2412 - val_accuracy: 0.8333 - val_loss: 0.4970
# Epoch 1913/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.9705 - loss: 0.0980 - val_accuracy: 0.8333 - val_loss: 0.5107
# Epoch 1914/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - accuracy: 0.9488 - loss: 0.1892 - val_accuracy: 0.8333 - val_loss: 0.5208
# Epoch 1915/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9527 - loss: 0.1750 - val_accuracy: 0.8333 - val_loss: 0.4968
# Epoch 1916/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9705 - loss: 0.1016 - val_accuracy: 0.8333 - val_loss: 0.5243
# Epoch 1917/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9813 - loss: 0.1113 - val_accuracy: 0.8333 - val_loss: 0.5301
# Epoch 1918/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9488 - loss: 0.1380 - val_accuracy: 0.8333 - val_loss: 0.5428
# Epoch 1919/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9536 - loss: 0.1461 - val_accuracy: 0.8333 - val_loss: 0.5308
# Epoch 1920/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9449 - loss: 0.1274 - val_accuracy: 0.8889 - val_loss: 0.4172
# Epoch 1921/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8867 - loss: 0.3049 - val_accuracy: 0.8889 - val_loss: 0.5471
# Epoch 1922/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9123 - loss: 0.2823 - val_accuracy: 0.8889 - val_loss: 0.6235
# Epoch 1923/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.9084 - loss: 0.1911 - val_accuracy: 0.8333 - val_loss: 0.5623
# Epoch 1924/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9145 - loss: 0.1962 - val_accuracy: 0.8333 - val_loss: 0.5973
# Epoch 1925/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.9518 - loss: 0.2340 - val_accuracy: 0.8333 - val_loss: 0.5591
# Epoch 1926/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9418 - loss: 0.1855 - val_accuracy: 0.8333 - val_loss: 0.4197
# Epoch 1927/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9931 - loss: 0.0786 - val_accuracy: 0.8333 - val_loss: 0.3953
# Epoch 1928/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9193 - loss: 0.2350 - val_accuracy: 0.8333 - val_loss: 0.4371
# Epoch 1929/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.9340 - loss: 0.2612 - val_accuracy: 0.8333 - val_loss: 0.4599
# Epoch 1930/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8798 - loss: 0.2781 - val_accuracy: 0.8889 - val_loss: 0.4860
# Epoch 1931/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9332 - loss: 0.1720 - val_accuracy: 0.8889 - val_loss: 0.4815
# Epoch 1932/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9253 - loss: 0.2590 - val_accuracy: 0.8889 - val_loss: 0.4710
# Epoch 1933/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9418 - loss: 0.2113 - val_accuracy: 0.8333 - val_loss: 0.5714
# Epoch 1934/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.8555 - loss: 0.4228 - val_accuracy: 0.8889 - val_loss: 0.3296
# Epoch 1935/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8898 - loss: 0.2941 - val_accuracy: 0.8889 - val_loss: 0.3472
# Epoch 1936/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9627 - loss: 0.0989 - val_accuracy: 0.8889 - val_loss: 0.3594
# Epoch 1937/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - accuracy: 0.9488 - loss: 0.1618 - val_accuracy: 0.8889 - val_loss: 0.3738
# Epoch 1938/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 0.9115 - loss: 0.2492 - val_accuracy: 0.8889 - val_loss: 0.4028
# Epoch 1939/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.9635 - loss: 0.1146 - val_accuracy: 0.8889 - val_loss: 0.4131
# Epoch 1940/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9783 - loss: 0.1035 - val_accuracy: 0.8889 - val_loss: 0.3981
# Epoch 1941/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.9518 - loss: 0.1210 - val_accuracy: 0.9444 - val_loss: 0.3958
# Epoch 1942/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9379 - loss: 0.2109 - val_accuracy: 0.9444 - val_loss: 0.4140
# Epoch 1943/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9783 - loss: 0.1064 - val_accuracy: 0.9444 - val_loss: 0.4252
# Epoch 1944/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9410 - loss: 0.2197 - val_accuracy: 0.8889 - val_loss: 0.4271
# Epoch 1945/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8889 - loss: 0.2716 - val_accuracy: 0.9444 - val_loss: 0.4265
# Epoch 1946/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9635 - loss: 0.1371 - val_accuracy: 0.9444 - val_loss: 0.4240
# Epoch 1947/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9410 - loss: 0.1852 - val_accuracy: 0.9444 - val_loss: 0.4566
# Epoch 1948/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9536 - loss: 0.1276 - val_accuracy: 0.8889 - val_loss: 0.4813
# Epoch 1949/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9184 - loss: 0.2415 - val_accuracy: 0.8333 - val_loss: 0.4962
# Epoch 1950/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9067 - loss: 0.1441 - val_accuracy: 0.8889 - val_loss: 0.4971
# Epoch 1951/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9488 - loss: 0.1644 - val_accuracy: 0.8889 - val_loss: 0.6523
# Epoch 1952/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9418 - loss: 0.1157 - val_accuracy: 0.7778 - val_loss: 2.0876
# Epoch 1953/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9822 - loss: 0.0781 - val_accuracy: 0.7778 - val_loss: 1.8133
# Epoch 1954/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.8958 - loss: 0.2854 - val_accuracy: 0.7778 - val_loss: 1.8188
# Epoch 1955/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9557 - loss: 0.1525 - val_accuracy: 0.7778 - val_loss: 2.1848
# Epoch 1956/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9635 - loss: 0.1455 - val_accuracy: 0.7778 - val_loss: 2.0265
# Epoch 1957/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.9449 - loss: 0.1477 - val_accuracy: 0.7778 - val_loss: 1.8122
# Epoch 1958/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9301 - loss: 0.2490 - val_accuracy: 0.8333 - val_loss: 1.4651
# Epoch 1959/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9891 - loss: 0.0815 - val_accuracy: 0.8333 - val_loss: 1.5217
# Epoch 1960/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9340 - loss: 0.1637 - val_accuracy: 0.8333 - val_loss: 0.3075
# Epoch 1961/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9527 - loss: 0.2059 - val_accuracy: 0.8333 - val_loss: 0.3765
# Epoch 1962/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9596 - loss: 0.1201 - val_accuracy: 0.8333 - val_loss: 0.3707
# Epoch 1963/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9488 - loss: 0.1966 - val_accuracy: 0.8333 - val_loss: 0.4738
# Epoch 1964/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.9123 - loss: 0.2308 - val_accuracy: 0.8889 - val_loss: 0.2476
# Epoch 1965/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - accuracy: 0.8976 - loss: 0.2526 - val_accuracy: 0.8889 - val_loss: 0.2339
# Epoch 1966/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.9076 - loss: 0.2477 - val_accuracy: 0.8889 - val_loss: 0.2915
# Epoch 1967/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 0.9627 - loss: 0.1613 - val_accuracy: 0.8889 - val_loss: 0.2748
# Epoch 1968/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8859 - loss: 0.3299 - val_accuracy: 0.8333 - val_loss: 0.2864
# Epoch 1969/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 0.0861 - val_accuracy: 0.8333 - val_loss: 0.2870
# Epoch 1970/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.9705 - loss: 0.1584 - val_accuracy: 0.8333 - val_loss: 0.2893
# Epoch 1971/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.9813 - loss: 0.1422 - val_accuracy: 0.8333 - val_loss: 0.2965
# Epoch 1972/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9253 - loss: 0.2395 - val_accuracy: 0.8333 - val_loss: 0.2842
# Epoch 1973/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9410 - loss: 0.1955 - val_accuracy: 0.8889 - val_loss: 0.2895
# Epoch 1974/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9596 - loss: 0.2129 - val_accuracy: 0.8333 - val_loss: 0.2906
# Epoch 1975/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9232 - loss: 0.2371 - val_accuracy: 0.8333 - val_loss: 0.2815
# Epoch 1976/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9301 - loss: 0.2252 - val_accuracy: 0.8333 - val_loss: 0.3509
# Epoch 1977/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.9813 - loss: 0.1041 - val_accuracy: 0.8333 - val_loss: 0.3707
# Epoch 1978/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.9488 - loss: 0.1573 - val_accuracy: 0.8333 - val_loss: 0.3893
# Epoch 1979/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9262 - loss: 0.1785 - val_accuracy: 0.8889 - val_loss: 0.3205
# Epoch 1980/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9705 - loss: 0.1254 - val_accuracy: 0.8889 - val_loss: 0.3288
# Epoch 1981/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9627 - loss: 0.1504 - val_accuracy: 0.8889 - val_loss: 0.3026
# Epoch 1982/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.9301 - loss: 0.1871 - val_accuracy: 0.8889 - val_loss: 0.3087
# Epoch 1983/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9705 - loss: 0.1100 - val_accuracy: 0.8889 - val_loss: 0.3168
# Epoch 1984/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9193 - loss: 0.2216 - val_accuracy: 0.8889 - val_loss: 0.3083
# Epoch 1985/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9488 - loss: 0.1765 - val_accuracy: 0.8889 - val_loss: 0.3147
# Epoch 1986/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.9427 - loss: 0.2229 - val_accuracy: 0.8889 - val_loss: 0.3247
# Epoch 1987/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.8212 - loss: 0.2750 - val_accuracy: 0.8889 - val_loss: 0.3654
# Epoch 1988/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9605 - loss: 0.1888 - val_accuracy: 0.8889 - val_loss: 0.3329
# Epoch 1989/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9457 - loss: 0.1633 - val_accuracy: 0.8889 - val_loss: 0.3362
# Epoch 1990/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.9084 - loss: 0.3009 - val_accuracy: 0.8889 - val_loss: 0.3798
# Epoch 1991/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - accuracy: 0.9566 - loss: 0.1394 - val_accuracy: 0.8889 - val_loss: 0.3752
# Epoch 1992/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 0.9705 - loss: 0.1035 - val_accuracy: 0.8889 - val_loss: 0.3607
# Epoch 1993/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9340 - loss: 0.1356 - val_accuracy: 0.8889 - val_loss: 0.3609
# Epoch 1994/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9605 - loss: 0.1918 - val_accuracy: 0.8889 - val_loss: 0.3788
# Epoch 1995/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9223 - loss: 0.2310 - val_accuracy: 0.8333 - val_loss: 0.4016
# Epoch 1996/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9410 - loss: 0.2069 - val_accuracy: 0.8889 - val_loss: 0.3524
# Epoch 1997/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9627 - loss: 0.1309 - val_accuracy: 0.8333 - val_loss: 0.4131
# Epoch 1998/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9705 - loss: 0.1213 - val_accuracy: 0.8889 - val_loss: 0.4276
# Epoch 1999/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9705 - loss: 0.1487 - val_accuracy: 0.8889 - val_loss: 0.4111
# Epoch 2000/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9232 - loss: 0.1932 - val_accuracy: 0.8333 - val_loss: 0.6058
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 128, 128, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 65536)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       8,388,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,409,804 (32.08 MB)
#  Trainable params: 8,409,610 (32.08 MB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# # Create Test Dataset

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_folder, labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size= batch_size,
    shuffle=True,
    validation_split=validation_split,
    subset='training',
    seed=123
  )
# Out:
# Found 30 files belonging to 6 classes.
# Using 24 files for training.

# %% [markdown]
# # Evaluate the Model

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_ds)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.3750 - loss: 920.2541
# Test Loss: 920.2541
# Test Accuracy: 0.3750

# %% [markdown]
# # Save and Load the Model

# %%
# Save the model
model.save('trained_model.h5')

# Load the model
loaded_model = keras.models.load_model('trained_model.h5')

# Re-evaluate the model on the test set
test_loss, test_accuracy = loaded_model.evaluate(test_ds)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 886ms/step - accuracy: 0.3750 - loss: 920.2541
# Test Loss: 920.2541
# Test Accuracy: 0.3750

# %% [markdown]
# # Classification Report and Training History

# %%
import numpy as np
from sklearn.metrics import classification_report

# Get true labels and predictions
y_true = []
y_pred = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())
    predictions = loaded_model.predict(images)
    y_pred.extend(np.argmax(predictions, axis=1))

# Classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot training history
def plot_history(history):
    plt.figure(figsize=(12, 5))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
#               precision    recall  f1-score   support
#
#      guarana       1.00      0.25      0.40         4
#     graviola       0.40      1.00      0.57         4
#      cupuacu       1.00      0.50      0.67         4
#         acai       0.00      0.00      0.00         3
#       tucuma       0.00      0.00      0.00         5
#      pupunha       0.18      0.50      0.27         4
#
#     accuracy                           0.38        24
#    macro avg       0.43      0.38      0.32        24
# weighted avg       0.43      0.38      0.32        24
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # TASK-02: Transfer Learning

# %% [markdown]
# # Load and Freeze Base Model

# %%
from tensorflow.keras.applications import VGG16

# Load VGG16 without the top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze all layers so their weights won't change during training
for layer in base_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# # Add Custom Classification Layers

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# Add custom classification layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)           # Flatten the output
x = Dense(1024, activation='relu')(x)     # Fully connected layer
outputs = Dense(10, activation='softmax')(x)  # Output layer (10 classes)

# Create the full model
model = Model(inputs=base_model.input, outputs=outputs)

# %%
from tensorflow.keras.optimizers import Adam

model.compile(
    optimizer=Adam(),
    loss='sparse_categorical_crossentropy',  # Change to 'categorical_crossentropy' if needed
    metrics=['accuracy']
)

# %% [markdown]
# # Compile the Transfer Learning Model

# %%
# If using image_dataset_from_directory
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/AI_ShivaSir/FruitinAmazon/train',
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/AI_ShivaSir/FruitinAmazon/train',
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 90 files belonging to 6 classes.
# Found 90 files belonging to 6 classes.

# %% [markdown]
# # Train the Transfer Learning Model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.1522 - loss: 9.4273
# WARNING:tensorflow:5 out of the last 8055 calls to <function TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator at 0x79a00c651e40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 7s/step - accuracy: 0.1697 - loss: 9.1099 - val_accuracy: 0.5667 - val_loss: 2.9308
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 442ms/step - accuracy: 0.6117 - loss: 2.3459 - val_accuracy: 0.8222 - val_loss: 0.5634
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 487ms/step - accuracy: 0.8050 - loss: 0.6536 - val_accuracy: 0.9667 - val_loss: 0.1343
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 491ms/step - accuracy: 0.9811 - loss: 0.0527 - val_accuracy: 0.9889 - val_loss: 0.0301
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 470ms/step - accuracy: 0.9755 - loss: 0.0551 - val_accuracy: 0.9889 - val_loss: 0.0400
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 488ms/step - accuracy: 0.9827 - loss: 0.0513 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 471ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 436ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 472ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0027

# %% [markdown]
# # Plot Training History (Transfer Learning)

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
